# %% [markdown]
# <a href="https://colab.research.google.com/github/kevin801221/-/blob/main/C1_W1_Lab_2_multi_output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %%
## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 910us/sample - loss: 259.9966 - y1_output_loss: 126.5574 - y2_output_loss: 130.9504 - y1_output_root_mean_squared_error: 11.3038 - y2_output_root_mean_squared_error: 11.4987 - val_loss: 29.4949 - val_y1_output_loss: 12.0973 - val_y2_output_loss: 18.6383 - val_y1_output_root_mean_squared_error: 3.4407 - val_y2_output_root_mean_squared_error: 4.2020
# Epoch 2/500
# 614/614 [==============================] - 0s 140us/sample - loss: 35.7069 - y1_output_loss: 13.5298 - y2_output_loss: 22.0837 - y1_output_root_mean_squared_error: 3.6685 - y2_output_root_mean_squared_error: 4.7169 - val_loss: 45.1181 - val_y1_output_loss: 13.1092 - val_y2_output_loss: 30.6193 - val_y1_output_root_mean_squared_error: 3.6749 - val_y2_output_root_mean_squared_error: 5.6226
# Epoch 3/500
# 614/614 [==============================] - 0s 131us/sample - loss: 29.9403 - y1_output_loss: 11.4873 - y2_output_loss: 19.0323 - y1_output_root_mean_squared_error: 3.3801 - y2_output_root_mean_squared_error: 4.3029 - val_loss: 187.3872 - val_y1_output_loss: 26.9591 - val_y2_output_loss: 154.3564 - val_y1_output_root_mean_squared_error: 5.2909 - val_y2_output_root_mean_squared_error: 12.6251
# Epoch 4/500
# 614/614 [==============================] - 0s 134us/sample - loss: 29.4412 - y1_output_loss: 10.6620 - y2_output_loss: 18.6477 - y1_output_root_mean_squared_error: 3.2653 - y2_output_root_mean_squared_error: 4.3334 - val_loss: 25.7340 - val_y1_output_loss: 9.6672 - val_y2_output_loss: 15.5792 - val_y1_output_root_mean_squared_error: 3.1470 - val_y2_output_root_mean_squared_error: 3.9787
# Epoch 5/500
# 614/614 [==============================] - 0s 133us/sample - loss: 25.1846 - y1_output_loss: 9.7669 - y2_output_loss: 16.1312 - y1_output_root_mean_squared_error: 3.0955 - y2_output_root_mean_squared_error: 3.9500 - val_loss: 151.8749 - val_y1_output_loss: 34.9722 - val_y2_output_loss: 116.5065 - val_y1_output_root_mean_squared_error: 5.9460 - val_y2_output_root_mean_squared_error: 10.7944
# Epoch 6/500
# 614/614 [==============================] - 0s 135us/sample - loss: 26.8732 - y1_output_loss: 10.0259 - y2_output_loss: 16.7081 - y1_output_root_mean_squared_error: 3.1660 - y2_output_root_mean_squared_error: 4.1048 - val_loss: 16.1458 - val_y1_output_loss: 7.0351 - val_y2_output_loss: 9.2668 - val_y1_output_root_mean_squared_error: 2.6698 - val_y2_output_root_mean_squared_error: 3.0030
# Epoch 7/500
# 614/614 [==============================] - 0s 130us/sample - loss: 24.0402 - y1_output_loss: 9.3316 - y2_output_loss: 14.5552 - y1_output_root_mean_squared_error: 3.0645 - y2_output_root_mean_squared_error: 3.8274 - val_loss: 30.2928 - val_y1_output_loss: 9.3201 - val_y2_output_loss: 21.5868 - val_y1_output_root_mean_squared_error: 3.0448 - val_y2_output_root_mean_squared_error: 4.5850
# Epoch 8/500
# 614/614 [==============================] - 0s 130us/sample - loss: 21.1647 - y1_output_loss: 8.6258 - y2_output_loss: 12.5340 - y1_output_root_mean_squared_error: 2.9241 - y2_output_root_mean_squared_error: 3.5516 - val_loss: 16.3371 - val_y1_output_loss: 6.8008 - val_y2_output_loss: 9.5946 - val_y1_output_root_mean_squared_error: 2.6264 - val_y2_output_root_mean_squared_error: 3.0723
# Epoch 9/500
# 614/614 [==============================] - 0s 130us/sample - loss: 22.0767 - y1_output_loss: 8.7672 - y2_output_loss: 13.2660 - y1_output_root_mean_squared_error: 2.9554 - y2_output_root_mean_squared_error: 3.6527 - val_loss: 25.3965 - val_y1_output_loss: 9.7429 - val_y2_output_loss: 15.0693 - val_y1_output_root_mean_squared_error: 3.1657 - val_y2_output_root_mean_squared_error: 3.9211
# Epoch 10/500
# 614/614 [==============================] - 0s 131us/sample - loss: 22.8472 - y1_output_loss: 8.7444 - y2_output_loss: 13.9374 - y1_output_root_mean_squared_error: 2.9687 - y2_output_root_mean_squared_error: 3.7462 - val_loss: 13.6121 - val_y1_output_loss: 5.7124 - val_y2_output_loss: 7.9555 - val_y1_output_root_mean_squared_error: 2.4010 - val_y2_output_root_mean_squared_error: 2.8013
# Epoch 11/500
# 614/614 [==============================] - 0s 131us/sample - loss: 19.9852 - y1_output_loss: 8.1470 - y2_output_loss: 11.8983 - y1_output_root_mean_squared_error: 2.8337 - y2_output_root_mean_squared_error: 3.4577 - val_loss: 17.0911 - val_y1_output_loss: 6.7372 - val_y2_output_loss: 9.8657 - val_y1_output_root_mean_squared_error: 2.6406 - val_y2_output_root_mean_squared_error: 3.1809
# Epoch 12/500
# 614/614 [==============================] - 0s 129us/sample - loss: 22.0465 - y1_output_loss: 8.2088 - y2_output_loss: 13.6438 - y1_output_root_mean_squared_error: 2.8776 - y2_output_root_mean_squared_error: 3.7103 - val_loss: 13.0563 - val_y1_output_loss: 5.3521 - val_y2_output_loss: 7.7256 - val_y1_output_root_mean_squared_error: 2.3314 - val_y2_output_root_mean_squared_error: 2.7606
# Epoch 13/500
# 614/614 [==============================] - 0s 142us/sample - loss: 21.2936 - y1_output_loss: 8.0218 - y2_output_loss: 13.0908 - y1_output_root_mean_squared_error: 2.8441 - y2_output_root_mean_squared_error: 3.6339 - val_loss: 13.8488 - val_y1_output_loss: 5.7776 - val_y2_output_loss: 8.2976 - val_y1_output_root_mean_squared_error: 2.4073 - val_y2_output_root_mean_squared_error: 2.8379
# Epoch 14/500
# 614/614 [==============================] - 0s 133us/sample - loss: 17.7644 - y1_output_loss: 6.9703 - y2_output_loss: 10.6780 - y1_output_root_mean_squared_error: 2.6455 - y2_output_root_mean_squared_error: 3.2811 - val_loss: 14.0615 - val_y1_output_loss: 5.5803 - val_y2_output_loss: 8.7210 - val_y1_output_root_mean_squared_error: 2.3705 - val_y2_output_root_mean_squared_error: 2.9055
# Epoch 15/500
# 614/614 [==============================] - 0s 131us/sample - loss: 17.2905 - y1_output_loss: 6.8110 - y2_output_loss: 10.4683 - y1_output_root_mean_squared_error: 2.6112 - y2_output_root_mean_squared_error: 3.2360 - val_loss: 12.3820 - val_y1_output_loss: 4.5953 - val_y2_output_loss: 7.7026 - val_y1_output_root_mean_squared_error: 2.1510 - val_y2_output_root_mean_squared_error: 2.7848
# Epoch 16/500
# 614/614 [==============================] - 0s 131us/sample - loss: 19.4678 - y1_output_loss: 7.3753 - y2_output_loss: 12.2320 - y1_output_root_mean_squared_error: 2.7189 - y2_output_root_mean_squared_error: 3.4750 - val_loss: 32.5611 - val_y1_output_loss: 6.6702 - val_y2_output_loss: 26.0986 - val_y1_output_root_mean_squared_error: 2.5972 - val_y2_output_root_mean_squared_error: 5.0809
# Epoch 17/500
# 614/614 [==============================] - 0s 132us/sample - loss: 17.0749 - y1_output_loss: 6.8426 - y2_output_loss: 10.2851 - y1_output_root_mean_squared_error: 2.6059 - y2_output_root_mean_squared_error: 3.2069 - val_loss: 14.9774 - val_y1_output_loss: 5.3712 - val_y2_output_loss: 9.0855 - val_y1_output_root_mean_squared_error: 2.3597 - val_y2_output_root_mean_squared_error: 3.0675
# Epoch 18/500
# 614/614 [==============================] - 0s 128us/sample - loss: 18.5742 - y1_output_loss: 6.8382 - y2_output_loss: 11.7954 - y1_output_root_mean_squared_error: 2.6184 - y2_output_root_mean_squared_error: 3.4232 - val_loss: 18.0835 - val_y1_output_loss: 5.5471 - val_y2_output_loss: 12.7407 - val_y1_output_root_mean_squared_error: 2.3681 - val_y2_output_root_mean_squared_error: 3.5321
# Epoch 19/500
# 614/614 [==============================] - 0s 129us/sample - loss: 19.7544 - y1_output_loss: 6.7179 - y2_output_loss: 12.9780 - y1_output_root_mean_squared_error: 2.5896 - y2_output_root_mean_squared_error: 3.6122 - val_loss: 12.1353 - val_y1_output_loss: 5.1528 - val_y2_output_loss: 7.0626 - val_y1_output_root_mean_squared_error: 2.2832 - val_y2_output_root_mean_squared_error: 2.6310
# Epoch 20/500
# 614/614 [==============================] - 0s 131us/sample - loss: 16.9352 - y1_output_loss: 6.1828 - y2_output_loss: 10.6075 - y1_output_root_mean_squared_error: 2.4972 - y2_output_root_mean_squared_error: 3.2709 - val_loss: 9.9136 - val_y1_output_loss: 4.2461 - val_y2_output_loss: 5.5991 - val_y1_output_root_mean_squared_error: 2.0830 - val_y2_output_root_mean_squared_error: 2.3611
# Epoch 21/500
# 614/614 [==============================] - 0s 130us/sample - loss: 14.8974 - y1_output_loss: 5.4543 - y2_output_loss: 9.5963 - y1_output_root_mean_squared_error: 2.3378 - y2_output_root_mean_squared_error: 3.0711 - val_loss: 28.4002 - val_y1_output_loss: 5.7898 - val_y2_output_loss: 21.6763 - val_y1_output_root_mean_squared_error: 2.4475 - val_y2_output_root_mean_squared_error: 4.7339
# Epoch 22/500
# 614/614 [==============================] - 0s 131us/sample - loss: 17.1784 - y1_output_loss: 5.8462 - y2_output_loss: 11.2637 - y1_output_root_mean_squared_error: 2.4264 - y2_output_root_mean_squared_error: 3.3602 - val_loss: 12.6999 - val_y1_output_loss: 4.0252 - val_y2_output_loss: 8.2436 - val_y1_output_root_mean_squared_error: 2.0407 - val_y2_output_root_mean_squared_error: 2.9215
# Epoch 23/500
# 614/614 [==============================] - 0s 129us/sample - loss: 11.5188 - y1_output_loss: 4.5109 - y2_output_loss: 6.9231 - y1_output_root_mean_squared_error: 2.1322 - y2_output_root_mean_squared_error: 2.6405 - val_loss: 15.8981 - val_y1_output_loss: 4.8741 - val_y2_output_loss: 10.4687 - val_y1_output_root_mean_squared_error: 2.2446 - val_y2_output_root_mean_squared_error: 3.2954
# Epoch 24/500
# 614/614 [==============================] - 0s 135us/sample - loss: 11.6461 - y1_output_loss: 4.4302 - y2_output_loss: 7.3187 - y1_output_root_mean_squared_error: 2.1069 - y2_output_root_mean_squared_error: 2.6846 - val_loss: 8.8126 - val_y1_output_loss: 3.4320 - val_y2_output_loss: 5.3253 - val_y1_output_root_mean_squared_error: 1.8652 - val_y2_output_root_mean_squared_error: 2.3095
# Epoch 25/500
# 614/614 [==============================] - 0s 132us/sample - loss: 12.7989 - y1_output_loss: 4.5439 - y2_output_loss: 8.3384 - y1_output_root_mean_squared_error: 2.1299 - y2_output_root_mean_squared_error: 2.8744 - val_loss: 34.1114 - val_y1_output_loss: 8.4246 - val_y2_output_loss: 25.4487 - val_y1_output_root_mean_squared_error: 2.9373 - val_y2_output_root_mean_squared_error: 5.0481
# Epoch 26/500
# 614/614 [==============================] - 0s 127us/sample - loss: 12.1951 - y1_output_loss: 4.4882 - y2_output_loss: 7.6559 - y1_output_root_mean_squared_error: 2.1216 - y2_output_root_mean_squared_error: 2.7738 - val_loss: 19.5984 - val_y1_output_loss: 6.7998 - val_y2_output_loss: 12.4732 - val_y1_output_root_mean_squared_error: 2.6472 - val_y2_output_root_mean_squared_error: 3.5484
# Epoch 27/500
# 614/614 [==============================] - 0s 130us/sample - loss: 12.7257 - y1_output_loss: 4.6379 - y2_output_loss: 8.1946 - y1_output_root_mean_squared_error: 2.1407 - y2_output_root_mean_squared_error: 2.8536 - val_loss: 12.4829 - val_y1_output_loss: 3.0671 - val_y2_output_loss: 8.9861 - val_y1_output_root_mean_squared_error: 1.7803 - val_y2_output_root_mean_squared_error: 3.0518
# Epoch 28/500
# 614/614 [==============================] - 0s 131us/sample - loss: 10.6901 - y1_output_loss: 3.8534 - y2_output_loss: 6.8747 - y1_output_root_mean_squared_error: 1.9640 - y2_output_root_mean_squared_error: 2.6140 - val_loss: 16.0158 - val_y1_output_loss: 5.0512 - val_y2_output_loss: 11.0171 - val_y1_output_root_mean_squared_error: 2.2683 - val_y2_output_root_mean_squared_error: 3.2970
# Epoch 29/500
# 614/614 [==============================] - 0s 132us/sample - loss: 11.2815 - y1_output_loss: 3.8973 - y2_output_loss: 7.3394 - y1_output_root_mean_squared_error: 1.9773 - y2_output_root_mean_squared_error: 2.7151 - val_loss: 8.1592 - val_y1_output_loss: 2.8500 - val_y2_output_loss: 5.1723 - val_y1_output_root_mean_squared_error: 1.7180 - val_y2_output_root_mean_squared_error: 2.2820
# Epoch 30/500
# 614/614 [==============================] - 0s 131us/sample - loss: 12.5009 - y1_output_loss: 4.5234 - y2_output_loss: 7.8782 - y1_output_root_mean_squared_error: 2.1359 - y2_output_root_mean_squared_error: 2.8176 - val_loss: 6.8640 - val_y1_output_loss: 2.6660 - val_y2_output_loss: 4.1515 - val_y1_output_root_mean_squared_error: 1.6552 - val_y2_output_root_mean_squared_error: 2.0308
# Epoch 31/500
# 614/614 [==============================] - 0s 130us/sample - loss: 10.4059 - y1_output_loss: 3.5946 - y2_output_loss: 6.7407 - y1_output_root_mean_squared_error: 1.9027 - y2_output_root_mean_squared_error: 2.6050 - val_loss: 9.7064 - val_y1_output_loss: 2.4599 - val_y2_output_loss: 7.2565 - val_y1_output_root_mean_squared_error: 1.5944 - val_y2_output_root_mean_squared_error: 2.6767
# Epoch 32/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.4694 - y1_output_loss: 3.1091 - y2_output_loss: 5.3144 - y1_output_root_mean_squared_error: 1.7715 - y2_output_root_mean_squared_error: 2.3089 - val_loss: 12.4125 - val_y1_output_loss: 4.8595 - val_y2_output_loss: 7.1284 - val_y1_output_root_mean_squared_error: 2.2397 - val_y2_output_root_mean_squared_error: 2.7196
# Epoch 33/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.5487 - y1_output_loss: 3.3086 - y2_output_loss: 6.4104 - y1_output_root_mean_squared_error: 1.8038 - y2_output_root_mean_squared_error: 2.5090 - val_loss: 46.1188 - val_y1_output_loss: 13.9914 - val_y2_output_loss: 31.3696 - val_y1_output_root_mean_squared_error: 3.7958 - val_y2_output_root_mean_squared_error: 5.6312
# Epoch 34/500
# 614/614 [==============================] - 0s 129us/sample - loss: 11.1340 - y1_output_loss: 3.6433 - y2_output_loss: 7.6195 - y1_output_root_mean_squared_error: 1.8888 - y2_output_root_mean_squared_error: 2.7507 - val_loss: 26.3066 - val_y1_output_loss: 7.8443 - val_y2_output_loss: 17.9834 - val_y1_output_root_mean_squared_error: 2.8484 - val_y2_output_root_mean_squared_error: 4.2653
# Epoch 35/500
# 614/614 [==============================] - 0s 135us/sample - loss: 11.8131 - y1_output_loss: 3.7455 - y2_output_loss: 8.0191 - y1_output_root_mean_squared_error: 1.9374 - y2_output_root_mean_squared_error: 2.8389 - val_loss: 13.2961 - val_y1_output_loss: 3.2985 - val_y2_output_loss: 9.9050 - val_y1_output_root_mean_squared_error: 1.8468 - val_y2_output_root_mean_squared_error: 3.1441
# Epoch 36/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.2409 - y1_output_loss: 2.7086 - y2_output_loss: 5.4714 - y1_output_root_mean_squared_error: 1.6489 - y2_output_root_mean_squared_error: 2.3499 - val_loss: 8.0696 - val_y1_output_loss: 3.0634 - val_y2_output_loss: 4.8823 - val_y1_output_root_mean_squared_error: 1.7812 - val_y2_output_root_mean_squared_error: 2.2129
# Epoch 37/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.5393 - y1_output_loss: 2.8203 - y2_output_loss: 5.7174 - y1_output_root_mean_squared_error: 1.6769 - y2_output_root_mean_squared_error: 2.3932 - val_loss: 10.3604 - val_y1_output_loss: 3.6771 - val_y2_output_loss: 6.6441 - val_y1_output_root_mean_squared_error: 1.9438 - val_y2_output_root_mean_squared_error: 2.5656
# Epoch 38/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.6618 - y1_output_loss: 2.5712 - y2_output_loss: 5.1419 - y1_output_root_mean_squared_error: 1.5892 - y2_output_root_mean_squared_error: 2.2663 - val_loss: 14.6050 - val_y1_output_loss: 6.5916 - val_y2_output_loss: 7.6253 - val_y1_output_root_mean_squared_error: 2.6125 - val_y2_output_root_mean_squared_error: 2.7893
# Epoch 39/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.1056 - y1_output_loss: 2.9397 - y2_output_loss: 6.2341 - y1_output_root_mean_squared_error: 1.7118 - y2_output_root_mean_squared_error: 2.4850 - val_loss: 36.8575 - val_y1_output_loss: 12.3432 - val_y2_output_loss: 23.2023 - val_y1_output_root_mean_squared_error: 3.5757 - val_y2_output_root_mean_squared_error: 4.9063
# Epoch 40/500
# 614/614 [==============================] - 0s 135us/sample - loss: 9.2161 - y1_output_loss: 2.8359 - y2_output_loss: 6.4505 - y1_output_root_mean_squared_error: 1.6901 - y2_output_root_mean_squared_error: 2.5219 - val_loss: 5.9022 - val_y1_output_loss: 1.9288 - val_y2_output_loss: 3.7680 - val_y1_output_root_mean_squared_error: 1.4138 - val_y2_output_root_mean_squared_error: 1.9757
# Epoch 41/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.9186 - y1_output_loss: 3.0473 - y2_output_loss: 6.8088 - y1_output_root_mean_squared_error: 1.7503 - y2_output_root_mean_squared_error: 2.6182 - val_loss: 7.0497 - val_y1_output_loss: 2.5950 - val_y2_output_loss: 4.3208 - val_y1_output_root_mean_squared_error: 1.6410 - val_y2_output_root_mean_squared_error: 2.0873
# Epoch 42/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.8549 - y1_output_loss: 2.3219 - y2_output_loss: 4.5882 - y1_output_root_mean_squared_error: 1.5298 - y2_output_root_mean_squared_error: 2.1247 - val_loss: 22.3521 - val_y1_output_loss: 4.8441 - val_y2_output_loss: 17.3552 - val_y1_output_root_mean_squared_error: 2.2354 - val_y2_output_root_mean_squared_error: 4.1660
# Epoch 43/500
# 614/614 [==============================] - 0s 131us/sample - loss: 9.4133 - y1_output_loss: 2.7458 - y2_output_loss: 6.7560 - y1_output_root_mean_squared_error: 1.6530 - y2_output_root_mean_squared_error: 2.5847 - val_loss: 26.3527 - val_y1_output_loss: 6.3670 - val_y2_output_loss: 19.1636 - val_y1_output_root_mean_squared_error: 2.5581 - val_y2_output_root_mean_squared_error: 4.4507
# Epoch 44/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.0607 - y1_output_loss: 2.5481 - y2_output_loss: 6.4668 - y1_output_root_mean_squared_error: 1.5949 - y2_output_root_mean_squared_error: 2.5528 - val_loss: 5.9364 - val_y1_output_loss: 1.5633 - val_y2_output_loss: 4.3188 - val_y1_output_root_mean_squared_error: 1.2731 - val_y2_output_root_mean_squared_error: 2.0774
# Epoch 45/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.3740 - y1_output_loss: 1.9073 - y2_output_loss: 4.4407 - y1_output_root_mean_squared_error: 1.3775 - y2_output_root_mean_squared_error: 2.1158 - val_loss: 7.9370 - val_y1_output_loss: 2.4515 - val_y2_output_loss: 5.3009 - val_y1_output_root_mean_squared_error: 1.5670 - val_y2_output_root_mean_squared_error: 2.3412
# Epoch 46/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.7695 - y1_output_loss: 2.0917 - y2_output_loss: 4.7034 - y1_output_root_mean_squared_error: 1.4426 - y2_output_root_mean_squared_error: 2.1653 - val_loss: 4.6338 - val_y1_output_loss: 1.6867 - val_y2_output_loss: 2.8236 - val_y1_output_root_mean_squared_error: 1.3222 - val_y2_output_root_mean_squared_error: 1.6987
# Epoch 47/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.9636 - y1_output_loss: 2.4192 - y2_output_loss: 5.5866 - y1_output_root_mean_squared_error: 1.5424 - y2_output_root_mean_squared_error: 2.3632 - val_loss: 9.8350 - val_y1_output_loss: 3.3419 - val_y2_output_loss: 6.3234 - val_y1_output_root_mean_squared_error: 1.8613 - val_y2_output_root_mean_squared_error: 2.5240
# Epoch 48/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.7772 - y1_output_loss: 2.0413 - y2_output_loss: 4.7543 - y1_output_root_mean_squared_error: 1.4203 - y2_output_root_mean_squared_error: 2.1817 - val_loss: 10.3556 - val_y1_output_loss: 4.2943 - val_y2_output_loss: 5.7204 - val_y1_output_root_mean_squared_error: 2.1026 - val_y2_output_root_mean_squared_error: 2.4361
# Epoch 49/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.1028 - y1_output_loss: 2.0424 - y2_output_loss: 5.0107 - y1_output_root_mean_squared_error: 1.4326 - y2_output_root_mean_squared_error: 2.2473 - val_loss: 6.6347 - val_y1_output_loss: 1.8601 - val_y2_output_loss: 4.6708 - val_y1_output_root_mean_squared_error: 1.3890 - val_y2_output_root_mean_squared_error: 2.1692
# Epoch 50/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.1462 - y1_output_loss: 2.2207 - y2_output_loss: 4.9502 - y1_output_root_mean_squared_error: 1.4914 - y2_output_root_mean_squared_error: 2.2186 - val_loss: 10.4825 - val_y1_output_loss: 3.7758 - val_y2_output_loss: 6.5565 - val_y1_output_root_mean_squared_error: 1.9756 - val_y2_output_root_mean_squared_error: 2.5651
# Epoch 51/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.6880 - y1_output_loss: 1.9909 - y2_output_loss: 4.6837 - y1_output_root_mean_squared_error: 1.4135 - y2_output_root_mean_squared_error: 2.1656 - val_loss: 6.0441 - val_y1_output_loss: 2.6648 - val_y2_output_loss: 3.2401 - val_y1_output_root_mean_squared_error: 1.6402 - val_y2_output_root_mean_squared_error: 1.8314
# Epoch 52/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.4341 - y1_output_loss: 1.9959 - y2_output_loss: 4.4321 - y1_output_root_mean_squared_error: 1.4170 - y2_output_root_mean_squared_error: 2.1038 - val_loss: 5.0908 - val_y1_output_loss: 1.3440 - val_y2_output_loss: 3.5751 - val_y1_output_root_mean_squared_error: 1.1742 - val_y2_output_root_mean_squared_error: 1.9267
# Epoch 53/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.4744 - y1_output_loss: 1.5854 - y2_output_loss: 3.8726 - y1_output_root_mean_squared_error: 1.2570 - y2_output_root_mean_squared_error: 1.9734 - val_loss: 4.7855 - val_y1_output_loss: 1.7607 - val_y2_output_loss: 2.8856 - val_y1_output_root_mean_squared_error: 1.3444 - val_y2_output_root_mean_squared_error: 1.7257
# Epoch 54/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.1982 - y1_output_loss: 2.0540 - y2_output_loss: 5.1185 - y1_output_root_mean_squared_error: 1.4357 - y2_output_root_mean_squared_error: 2.2665 - val_loss: 9.3481 - val_y1_output_loss: 3.3097 - val_y2_output_loss: 5.7312 - val_y1_output_root_mean_squared_error: 1.8446 - val_y2_output_root_mean_squared_error: 2.4383
# Epoch 55/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.8238 - y1_output_loss: 1.4973 - y2_output_loss: 4.3582 - y1_output_root_mean_squared_error: 1.2285 - y2_output_root_mean_squared_error: 2.0772 - val_loss: 5.9843 - val_y1_output_loss: 1.3485 - val_y2_output_loss: 4.4643 - val_y1_output_root_mean_squared_error: 1.1684 - val_y2_output_root_mean_squared_error: 2.1492
# Epoch 56/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.6155 - y1_output_loss: 1.5103 - y2_output_loss: 4.1165 - y1_output_root_mean_squared_error: 1.2238 - y2_output_root_mean_squared_error: 2.0292 - val_loss: 4.9936 - val_y1_output_loss: 1.9803 - val_y2_output_loss: 2.8837 - val_y1_output_root_mean_squared_error: 1.4325 - val_y2_output_root_mean_squared_error: 1.7151
# Epoch 57/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.6709 - y1_output_loss: 1.9783 - y2_output_loss: 4.7462 - y1_output_root_mean_squared_error: 1.4005 - y2_output_root_mean_squared_error: 2.1701 - val_loss: 7.8170 - val_y1_output_loss: 3.1346 - val_y2_output_loss: 4.5087 - val_y1_output_root_mean_squared_error: 1.7978 - val_y2_output_root_mean_squared_error: 2.1412
# Epoch 58/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.1370 - y1_output_loss: 1.6910 - y2_output_loss: 4.4285 - y1_output_root_mean_squared_error: 1.2938 - y2_output_root_mean_squared_error: 2.1126 - val_loss: 4.1656 - val_y1_output_loss: 1.2691 - val_y2_output_loss: 2.8518 - val_y1_output_root_mean_squared_error: 1.1480 - val_y2_output_root_mean_squared_error: 1.6875
# Epoch 59/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.9606 - y1_output_loss: 2.1025 - y2_output_loss: 5.4306 - y1_output_root_mean_squared_error: 1.4038 - y2_output_root_mean_squared_error: 2.2338 - val_loss: 8.8491 - val_y1_output_loss: 3.0055 - val_y2_output_loss: 5.5469 - val_y1_output_root_mean_squared_error: 1.7628 - val_y2_output_root_mean_squared_error: 2.3962
# Epoch 60/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.7864 - y1_output_loss: 1.4988 - y2_output_loss: 4.2389 - y1_output_root_mean_squared_error: 1.2276 - y2_output_root_mean_squared_error: 2.0687 - val_loss: 4.4492 - val_y1_output_loss: 1.6500 - val_y2_output_loss: 2.7171 - val_y1_output_root_mean_squared_error: 1.3082 - val_y2_output_root_mean_squared_error: 1.6546
# Epoch 61/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.5579 - y1_output_loss: 1.2919 - y2_output_loss: 3.2258 - y1_output_root_mean_squared_error: 1.1420 - y2_output_root_mean_squared_error: 1.8038 - val_loss: 3.7425 - val_y1_output_loss: 1.3315 - val_y2_output_loss: 2.3355 - val_y1_output_root_mean_squared_error: 1.1746 - val_y2_output_root_mean_squared_error: 1.5372
# Epoch 62/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.0046 - y1_output_loss: 1.5498 - y2_output_loss: 4.4364 - y1_output_root_mean_squared_error: 1.2482 - y2_output_root_mean_squared_error: 2.1087 - val_loss: 5.9560 - val_y1_output_loss: 2.2098 - val_y2_output_loss: 3.6325 - val_y1_output_root_mean_squared_error: 1.5106 - val_y2_output_root_mean_squared_error: 1.9168
# Epoch 63/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.1929 - y1_output_loss: 1.5623 - y2_output_loss: 3.9145 - y1_output_root_mean_squared_error: 1.2365 - y2_output_root_mean_squared_error: 1.9141 - val_loss: 47.8936 - val_y1_output_loss: 15.2498 - val_y2_output_loss: 31.5917 - val_y1_output_root_mean_squared_error: 3.9337 - val_y2_output_root_mean_squared_error: 5.6938
# Epoch 64/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.6627 - y1_output_loss: 1.6410 - y2_output_loss: 3.9773 - y1_output_root_mean_squared_error: 1.2855 - y2_output_root_mean_squared_error: 2.0025 - val_loss: 5.7526 - val_y1_output_loss: 1.8039 - val_y2_output_loss: 3.8516 - val_y1_output_root_mean_squared_error: 1.3660 - val_y2_output_root_mean_squared_error: 1.9715
# Epoch 65/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.5626 - y1_output_loss: 1.2084 - y2_output_loss: 3.5206 - y1_output_root_mean_squared_error: 1.0907 - y2_output_root_mean_squared_error: 1.8366 - val_loss: 39.6557 - val_y1_output_loss: 10.8362 - val_y2_output_loss: 28.1266 - val_y1_output_root_mean_squared_error: 3.3471 - val_y2_output_root_mean_squared_error: 5.3341
# Epoch 66/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.4588 - y1_output_loss: 1.8747 - y2_output_loss: 4.5908 - y1_output_root_mean_squared_error: 1.3608 - y2_output_root_mean_squared_error: 2.1464 - val_loss: 4.0528 - val_y1_output_loss: 1.7497 - val_y2_output_loss: 2.2315 - val_y1_output_root_mean_squared_error: 1.3452 - val_y2_output_root_mean_squared_error: 1.4977
# Epoch 67/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.2489 - y1_output_loss: 1.2320 - y2_output_loss: 3.0153 - y1_output_root_mean_squared_error: 1.1060 - y2_output_root_mean_squared_error: 1.7394 - val_loss: 8.2639 - val_y1_output_loss: 3.2971 - val_y2_output_loss: 4.8088 - val_y1_output_root_mean_squared_error: 1.8483 - val_y2_output_root_mean_squared_error: 2.2018
# Epoch 68/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.1835 - y1_output_loss: 1.1220 - y2_output_loss: 3.1629 - y1_output_root_mean_squared_error: 1.0347 - y2_output_root_mean_squared_error: 1.7644 - val_loss: 18.7587 - val_y1_output_loss: 8.5935 - val_y2_output_loss: 9.5507 - val_y1_output_root_mean_squared_error: 2.9728 - val_y2_output_root_mean_squared_error: 3.1498
# Epoch 69/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.7168 - y1_output_loss: 1.4881 - y2_output_loss: 3.2135 - y1_output_root_mean_squared_error: 1.2248 - y2_output_root_mean_squared_error: 1.7935 - val_loss: 5.0420 - val_y1_output_loss: 1.5540 - val_y2_output_loss: 3.4196 - val_y1_output_root_mean_squared_error: 1.2642 - val_y2_output_root_mean_squared_error: 1.8557
# Epoch 70/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.1679 - y1_output_loss: 1.0852 - y2_output_loss: 3.0463 - y1_output_root_mean_squared_error: 1.0460 - y2_output_root_mean_squared_error: 1.7532 - val_loss: 3.6224 - val_y1_output_loss: 1.0971 - val_y2_output_loss: 2.4678 - val_y1_output_root_mean_squared_error: 1.0650 - val_y2_output_root_mean_squared_error: 1.5774
# Epoch 71/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.0317 - y1_output_loss: 1.0284 - y2_output_loss: 2.9987 - y1_output_root_mean_squared_error: 1.0183 - y2_output_root_mean_squared_error: 1.7306 - val_loss: 6.3216 - val_y1_output_loss: 1.5884 - val_y2_output_loss: 4.5264 - val_y1_output_root_mean_squared_error: 1.2737 - val_y2_output_root_mean_squared_error: 2.1678
# Epoch 72/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.3386 - y1_output_loss: 1.8026 - y2_output_loss: 3.5180 - y1_output_root_mean_squared_error: 1.3424 - y2_output_root_mean_squared_error: 1.8805 - val_loss: 4.1675 - val_y1_output_loss: 1.5432 - val_y2_output_loss: 2.5871 - val_y1_output_root_mean_squared_error: 1.2605 - val_y2_output_root_mean_squared_error: 1.6058
# Epoch 73/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.1564 - y1_output_loss: 0.9432 - y2_output_loss: 3.2059 - y1_output_root_mean_squared_error: 0.9736 - y2_output_root_mean_squared_error: 1.7913 - val_loss: 3.5131 - val_y1_output_loss: 1.1009 - val_y2_output_loss: 2.3170 - val_y1_output_root_mean_squared_error: 1.0634 - val_y2_output_root_mean_squared_error: 1.5435
# Epoch 74/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.5718 - y1_output_loss: 1.0515 - y2_output_loss: 3.5438 - y1_output_root_mean_squared_error: 1.0107 - y2_output_root_mean_squared_error: 1.8842 - val_loss: 3.0122 - val_y1_output_loss: 0.9369 - val_y2_output_loss: 1.9947 - val_y1_output_root_mean_squared_error: 0.9851 - val_y2_output_root_mean_squared_error: 1.4289
# Epoch 75/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.3418 - y1_output_loss: 2.4542 - y2_output_loss: 6.8061 - y1_output_root_mean_squared_error: 1.5739 - y2_output_root_mean_squared_error: 2.6201 - val_loss: 2.6736 - val_y1_output_loss: 0.7474 - val_y2_output_loss: 1.9006 - val_y1_output_root_mean_squared_error: 0.8789 - val_y2_output_root_mean_squared_error: 1.3788
# Epoch 76/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.7638 - y1_output_loss: 0.9027 - y2_output_loss: 2.8337 - y1_output_root_mean_squared_error: 0.9533 - y2_output_root_mean_squared_error: 1.6896 - val_loss: 3.1635 - val_y1_output_loss: 0.8117 - val_y2_output_loss: 2.3567 - val_y1_output_root_mean_squared_error: 0.9170 - val_y2_output_root_mean_squared_error: 1.5240
# Epoch 77/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.0011 - y1_output_loss: 0.7666 - y2_output_loss: 2.2389 - y1_output_root_mean_squared_error: 0.8696 - y2_output_root_mean_squared_error: 1.4983 - val_loss: 8.0259 - val_y1_output_loss: 2.7522 - val_y2_output_loss: 5.1819 - val_y1_output_root_mean_squared_error: 1.6875 - val_y2_output_root_mean_squared_error: 2.2756
# Epoch 78/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.9375 - y1_output_loss: 0.9905 - y2_output_loss: 2.9209 - y1_output_root_mean_squared_error: 0.9997 - y2_output_root_mean_squared_error: 1.7141 - val_loss: 3.2125 - val_y1_output_loss: 0.8602 - val_y2_output_loss: 2.2629 - val_y1_output_root_mean_squared_error: 0.9391 - val_y2_output_root_mean_squared_error: 1.5266
# Epoch 79/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.1832 - y1_output_loss: 1.0757 - y2_output_loss: 3.0958 - y1_output_root_mean_squared_error: 1.0374 - y2_output_root_mean_squared_error: 1.7626 - val_loss: 9.4677 - val_y1_output_loss: 2.5482 - val_y2_output_loss: 6.5844 - val_y1_output_root_mean_squared_error: 1.6211 - val_y2_output_root_mean_squared_error: 2.6153
# Epoch 80/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.1330 - y1_output_loss: 0.8074 - y2_output_loss: 2.3157 - y1_output_root_mean_squared_error: 0.8979 - y2_output_root_mean_squared_error: 1.5254 - val_loss: 4.2055 - val_y1_output_loss: 1.6869 - val_y2_output_loss: 2.4109 - val_y1_output_root_mean_squared_error: 1.3181 - val_y2_output_root_mean_squared_error: 1.5710
# Epoch 81/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.5031 - y1_output_loss: 1.0320 - y2_output_loss: 3.4478 - y1_output_root_mean_squared_error: 1.0141 - y2_output_root_mean_squared_error: 1.8641 - val_loss: 4.4214 - val_y1_output_loss: 1.1070 - val_y2_output_loss: 3.3060 - val_y1_output_root_mean_squared_error: 1.0713 - val_y2_output_root_mean_squared_error: 1.8093
# Epoch 82/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.1061 - y1_output_loss: 0.7081 - y2_output_loss: 2.3920 - y1_output_root_mean_squared_error: 0.8352 - y2_output_root_mean_squared_error: 1.5520 - val_loss: 2.9808 - val_y1_output_loss: 0.9337 - val_y2_output_loss: 1.9761 - val_y1_output_root_mean_squared_error: 0.9759 - val_y2_output_root_mean_squared_error: 1.4242
# Epoch 83/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.2456 - y1_output_loss: 0.6894 - y2_output_loss: 2.5297 - y1_output_root_mean_squared_error: 0.8340 - y2_output_root_mean_squared_error: 1.5969 - val_loss: 3.0165 - val_y1_output_loss: 0.7487 - val_y2_output_loss: 2.1883 - val_y1_output_root_mean_squared_error: 0.8638 - val_y2_output_root_mean_squared_error: 1.5067
# Epoch 84/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.6592 - y1_output_loss: 0.7710 - y2_output_loss: 2.9242 - y1_output_root_mean_squared_error: 0.8775 - y2_output_root_mean_squared_error: 1.6998 - val_loss: 6.9850 - val_y1_output_loss: 1.1274 - val_y2_output_loss: 5.6376 - val_y1_output_root_mean_squared_error: 1.0669 - val_y2_output_root_mean_squared_error: 2.4180
# Epoch 85/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.6137 - y1_output_loss: 0.8687 - y2_output_loss: 2.7240 - y1_output_root_mean_squared_error: 0.9320 - y2_output_root_mean_squared_error: 1.6568 - val_loss: 2.5037 - val_y1_output_loss: 0.7485 - val_y2_output_loss: 1.7160 - val_y1_output_root_mean_squared_error: 0.8778 - val_y2_output_root_mean_squared_error: 1.3165
# Epoch 86/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.0619 - y1_output_loss: 0.6389 - y2_output_loss: 2.4010 - y1_output_root_mean_squared_error: 0.7992 - y2_output_root_mean_squared_error: 1.5566 - val_loss: 2.5553 - val_y1_output_loss: 0.6726 - val_y2_output_loss: 1.8564 - val_y1_output_root_mean_squared_error: 0.8316 - val_y2_output_root_mean_squared_error: 1.3652
# Epoch 87/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.2187 - y1_output_loss: 0.8007 - y2_output_loss: 2.4547 - y1_output_root_mean_squared_error: 0.8948 - y2_output_root_mean_squared_error: 1.5550 - val_loss: 2.3993 - val_y1_output_loss: 0.5594 - val_y2_output_loss: 1.7723 - val_y1_output_root_mean_squared_error: 0.7529 - val_y2_output_root_mean_squared_error: 1.3537
# Epoch 88/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.0519 - y1_output_loss: 0.6122 - y2_output_loss: 2.4610 - y1_output_root_mean_squared_error: 0.7809 - y2_output_root_mean_squared_error: 1.5628 - val_loss: 2.3795 - val_y1_output_loss: 0.7424 - val_y2_output_loss: 1.6417 - val_y1_output_root_mean_squared_error: 0.8580 - val_y2_output_root_mean_squared_error: 1.2820
# Epoch 89/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.9558 - y1_output_loss: 0.8661 - y2_output_loss: 2.1096 - y1_output_root_mean_squared_error: 0.9275 - y2_output_root_mean_squared_error: 1.4476 - val_loss: 6.8150 - val_y1_output_loss: 2.4177 - val_y2_output_loss: 4.3075 - val_y1_output_root_mean_squared_error: 1.5819 - val_y2_output_root_mean_squared_error: 2.0767
# Epoch 90/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.7048 - y1_output_loss: 0.9378 - y2_output_loss: 2.7640 - y1_output_root_mean_squared_error: 0.9597 - y2_output_root_mean_squared_error: 1.6685 - val_loss: 3.4743 - val_y1_output_loss: 1.1577 - val_y2_output_loss: 2.2155 - val_y1_output_root_mean_squared_error: 1.0937 - val_y2_output_root_mean_squared_error: 1.5093
# Epoch 91/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.3164 - y1_output_loss: 0.5115 - y2_output_loss: 1.8135 - y1_output_root_mean_squared_error: 0.7166 - y2_output_root_mean_squared_error: 1.3427 - val_loss: 2.7896 - val_y1_output_loss: 0.5936 - val_y2_output_loss: 2.1101 - val_y1_output_root_mean_squared_error: 0.7770 - val_y2_output_root_mean_squared_error: 1.4784
# Epoch 92/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.5980 - y1_output_loss: 0.6147 - y2_output_loss: 1.9658 - y1_output_root_mean_squared_error: 0.7852 - y2_output_root_mean_squared_error: 1.4076 - val_loss: 2.0390 - val_y1_output_loss: 0.5331 - val_y2_output_loss: 1.4757 - val_y1_output_root_mean_squared_error: 0.7431 - val_y2_output_root_mean_squared_error: 1.2193
# Epoch 93/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.7469 - y1_output_loss: 0.5884 - y2_output_loss: 2.1379 - y1_output_root_mean_squared_error: 0.7706 - y2_output_root_mean_squared_error: 1.4673 - val_loss: 3.3553 - val_y1_output_loss: 1.0854 - val_y2_output_loss: 2.2586 - val_y1_output_root_mean_squared_error: 1.0521 - val_y2_output_root_mean_squared_error: 1.4995
# Epoch 94/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.1620 - y1_output_loss: 1.0157 - y2_output_loss: 3.1138 - y1_output_root_mean_squared_error: 1.0109 - y2_output_root_mean_squared_error: 1.7720 - val_loss: 6.7896 - val_y1_output_loss: 2.9290 - val_y2_output_loss: 3.6733 - val_y1_output_root_mean_squared_error: 1.7279 - val_y2_output_root_mean_squared_error: 1.9504
# Epoch 95/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.2963 - y1_output_loss: 1.4687 - y2_output_loss: 4.7779 - y1_output_root_mean_squared_error: 1.2148 - y2_output_root_mean_squared_error: 2.1956 - val_loss: 2.1855 - val_y1_output_loss: 0.5250 - val_y2_output_loss: 1.6697 - val_y1_output_root_mean_squared_error: 0.7296 - val_y2_output_root_mean_squared_error: 1.2858
# Epoch 96/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.3234 - y1_output_loss: 0.5904 - y2_output_loss: 1.7153 - y1_output_root_mean_squared_error: 0.7714 - y2_output_root_mean_squared_error: 1.3147 - val_loss: 1.8401 - val_y1_output_loss: 0.4442 - val_y2_output_loss: 1.3765 - val_y1_output_root_mean_squared_error: 0.6706 - val_y2_output_root_mean_squared_error: 1.1791
# Epoch 97/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.6165 - y1_output_loss: 0.6512 - y2_output_loss: 1.9515 - y1_output_root_mean_squared_error: 0.8083 - y2_output_root_mean_squared_error: 1.4011 - val_loss: 2.9841 - val_y1_output_loss: 0.9772 - val_y2_output_loss: 2.0635 - val_y1_output_root_mean_squared_error: 1.0025 - val_y2_output_root_mean_squared_error: 1.4068
# Epoch 98/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.7466 - y1_output_loss: 0.5961 - y2_output_loss: 2.1272 - y1_output_root_mean_squared_error: 0.7749 - y2_output_root_mean_squared_error: 1.4650 - val_loss: 2.4368 - val_y1_output_loss: 0.5898 - val_y2_output_loss: 1.7869 - val_y1_output_root_mean_squared_error: 0.7641 - val_y2_output_root_mean_squared_error: 1.3612
# Epoch 99/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.6396 - y1_output_loss: 0.6929 - y2_output_loss: 2.9163 - y1_output_root_mean_squared_error: 0.8352 - y2_output_root_mean_squared_error: 1.7152 - val_loss: 2.9234 - val_y1_output_loss: 0.7079 - val_y2_output_loss: 2.1695 - val_y1_output_root_mean_squared_error: 0.8446 - val_y2_output_root_mean_squared_error: 1.4866
# Epoch 100/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.5350 - y1_output_loss: 0.6923 - y2_output_loss: 1.8415 - y1_output_root_mean_squared_error: 0.8336 - y2_output_root_mean_squared_error: 1.3565 - val_loss: 3.3553 - val_y1_output_loss: 0.5513 - val_y2_output_loss: 2.8743 - val_y1_output_root_mean_squared_error: 0.7550 - val_y2_output_root_mean_squared_error: 1.6689
# Epoch 101/500
# 614/614 [==============================] - 0s 159us/sample - loss: 2.7092 - y1_output_loss: 0.6518 - y2_output_loss: 2.0326 - y1_output_root_mean_squared_error: 0.8107 - y2_output_root_mean_squared_error: 1.4325 - val_loss: 1.8666 - val_y1_output_loss: 0.4957 - val_y2_output_loss: 1.3604 - val_y1_output_root_mean_squared_error: 0.7013 - val_y2_output_root_mean_squared_error: 1.1725
# Epoch 102/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.6215 - y1_output_loss: 0.6415 - y2_output_loss: 2.0374 - y1_output_root_mean_squared_error: 0.7901 - y2_output_root_mean_squared_error: 1.4132 - val_loss: 31.0673 - val_y1_output_loss: 12.4317 - val_y2_output_loss: 17.6855 - val_y1_output_root_mean_squared_error: 3.5698 - val_y2_output_root_mean_squared_error: 4.2806
# Epoch 103/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.1099 - y1_output_loss: 1.0103 - y2_output_loss: 3.0885 - y1_output_root_mean_squared_error: 1.0066 - y2_output_root_mean_squared_error: 1.7597 - val_loss: 3.7588 - val_y1_output_loss: 1.3273 - val_y2_output_loss: 2.3513 - val_y1_output_root_mean_squared_error: 1.1736 - val_y2_output_root_mean_squared_error: 1.5432
# Epoch 104/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.4515 - y1_output_loss: 0.5655 - y2_output_loss: 1.9041 - y1_output_root_mean_squared_error: 0.7422 - y2_output_root_mean_squared_error: 1.3786 - val_loss: 7.6591 - val_y1_output_loss: 3.4605 - val_y2_output_loss: 3.9502 - val_y1_output_root_mean_squared_error: 1.8901 - val_y2_output_root_mean_squared_error: 2.0215
# Epoch 105/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.9782 - y1_output_loss: 0.7904 - y2_output_loss: 2.1767 - y1_output_root_mean_squared_error: 0.8845 - y2_output_root_mean_squared_error: 1.4819 - val_loss: 2.2322 - val_y1_output_loss: 0.6671 - val_y2_output_loss: 1.5468 - val_y1_output_root_mean_squared_error: 0.8178 - val_y2_output_root_mean_squared_error: 1.2504
# Epoch 106/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.4147 - y1_output_loss: 0.4856 - y2_output_loss: 1.9203 - y1_output_root_mean_squared_error: 0.6963 - y2_output_root_mean_squared_error: 1.3892 - val_loss: 5.2632 - val_y1_output_loss: 0.4761 - val_y2_output_loss: 4.8191 - val_y1_output_root_mean_squared_error: 0.6966 - val_y2_output_root_mean_squared_error: 2.1858
# Epoch 107/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.3225 - y1_output_loss: 0.4909 - y2_output_loss: 1.8244 - y1_output_root_mean_squared_error: 0.6970 - y2_output_root_mean_squared_error: 1.3552 - val_loss: 2.5882 - val_y1_output_loss: 0.4764 - val_y2_output_loss: 2.1772 - val_y1_output_root_mean_squared_error: 0.6970 - val_y2_output_root_mean_squared_error: 1.4500
# Epoch 108/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.7180 - y1_output_loss: 0.5762 - y2_output_loss: 2.1250 - y1_output_root_mean_squared_error: 0.7576 - y2_output_root_mean_squared_error: 1.4642 - val_loss: 2.0488 - val_y1_output_loss: 0.6178 - val_y2_output_loss: 1.4116 - val_y1_output_root_mean_squared_error: 0.7813 - val_y2_output_root_mean_squared_error: 1.1993
# Epoch 109/500
# 614/614 [==============================] - 0s 139us/sample - loss: 1.9945 - y1_output_loss: 0.3992 - y2_output_loss: 1.5796 - y1_output_root_mean_squared_error: 0.6342 - y2_output_root_mean_squared_error: 1.2619 - val_loss: 1.7409 - val_y1_output_loss: 0.4158 - val_y2_output_loss: 1.2956 - val_y1_output_root_mean_squared_error: 0.6497 - val_y2_output_root_mean_squared_error: 1.1484
# Epoch 110/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.1254 - y1_output_loss: 0.5345 - y2_output_loss: 1.5865 - y1_output_root_mean_squared_error: 0.7314 - y2_output_root_mean_squared_error: 1.2611 - val_loss: 3.3336 - val_y1_output_loss: 0.7613 - val_y2_output_loss: 2.5058 - val_y1_output_root_mean_squared_error: 0.8812 - val_y2_output_root_mean_squared_error: 1.5991
# Epoch 111/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.0690 - y1_output_loss: 0.4262 - y2_output_loss: 1.6448 - y1_output_root_mean_squared_error: 0.6540 - y2_output_root_mean_squared_error: 1.2812 - val_loss: 2.7223 - val_y1_output_loss: 0.6562 - val_y2_output_loss: 1.9960 - val_y1_output_root_mean_squared_error: 0.8128 - val_y2_output_root_mean_squared_error: 1.4359
# Epoch 112/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.0957 - y1_output_loss: 0.4452 - y2_output_loss: 1.6402 - y1_output_root_mean_squared_error: 0.6644 - y2_output_root_mean_squared_error: 1.2862 - val_loss: 2.3134 - val_y1_output_loss: 0.6601 - val_y2_output_loss: 1.5886 - val_y1_output_root_mean_squared_error: 0.8175 - val_y2_output_root_mean_squared_error: 1.2826
# Epoch 113/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.2389 - y1_output_loss: 1.5634 - y2_output_loss: 4.6920 - y1_output_root_mean_squared_error: 1.2545 - y2_output_root_mean_squared_error: 2.1599 - val_loss: 13.5138 - val_y1_output_loss: 2.2840 - val_y2_output_loss: 10.8923 - val_y1_output_root_mean_squared_error: 1.5159 - val_y2_output_root_mean_squared_error: 3.3490
# Epoch 114/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.6951 - y1_output_loss: 2.4122 - y2_output_loss: 6.2748 - y1_output_root_mean_squared_error: 1.5595 - y2_output_root_mean_squared_error: 2.5026 - val_loss: 10.9399 - val_y1_output_loss: 1.1847 - val_y2_output_loss: 9.4083 - val_y1_output_root_mean_squared_error: 1.1003 - val_y2_output_root_mean_squared_error: 3.1192
# Epoch 115/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.3740 - y1_output_loss: 0.5280 - y2_output_loss: 1.8316 - y1_output_root_mean_squared_error: 0.7289 - y2_output_root_mean_squared_error: 1.3575 - val_loss: 1.8476 - val_y1_output_loss: 0.5205 - val_y2_output_loss: 1.3089 - val_y1_output_root_mean_squared_error: 0.7309 - val_y2_output_root_mean_squared_error: 1.1460
# Epoch 116/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.1879 - y1_output_loss: 0.5045 - y2_output_loss: 1.6778 - y1_output_root_mean_squared_error: 0.7127 - y2_output_root_mean_squared_error: 1.2961 - val_loss: 1.8176 - val_y1_output_loss: 0.4092 - val_y2_output_loss: 1.3712 - val_y1_output_root_mean_squared_error: 0.6511 - val_y2_output_root_mean_squared_error: 1.1806
# Epoch 117/500
# 614/614 [==============================] - 0s 150us/sample - loss: 1.7922 - y1_output_loss: 0.4163 - y2_output_loss: 1.4259 - y1_output_root_mean_squared_error: 0.6387 - y2_output_root_mean_squared_error: 1.1765 - val_loss: 3.1242 - val_y1_output_loss: 0.6941 - val_y2_output_loss: 2.4044 - val_y1_output_root_mean_squared_error: 0.8478 - val_y2_output_root_mean_squared_error: 1.5510
# Epoch 118/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.2137 - y1_output_loss: 0.4674 - y2_output_loss: 1.7357 - y1_output_root_mean_squared_error: 0.6826 - y2_output_root_mean_squared_error: 1.3220 - val_loss: 2.8332 - val_y1_output_loss: 0.5448 - val_y2_output_loss: 2.2532 - val_y1_output_root_mean_squared_error: 0.7271 - val_y2_output_root_mean_squared_error: 1.5181
# Epoch 119/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.3685 - y1_output_loss: 1.2390 - y2_output_loss: 3.2058 - y1_output_root_mean_squared_error: 1.0955 - y2_output_root_mean_squared_error: 1.7800 - val_loss: 10.1024 - val_y1_output_loss: 2.1571 - val_y2_output_loss: 7.9791 - val_y1_output_root_mean_squared_error: 1.4885 - val_y2_output_root_mean_squared_error: 2.8083
# Epoch 120/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.9550 - y1_output_loss: 0.6808 - y2_output_loss: 2.2665 - y1_output_root_mean_squared_error: 0.8270 - y2_output_root_mean_squared_error: 1.5070 - val_loss: 4.3426 - val_y1_output_loss: 1.3600 - val_y2_output_loss: 2.9291 - val_y1_output_root_mean_squared_error: 1.1875 - val_y2_output_root_mean_squared_error: 1.7124
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3072 - y1_output_loss: 0.1039 - y2_output_loss: 0.2013 - y1_output_root_mean_squared_error: 0.3232 - y2_output_root_mean_squared_error: 0.4503 - val_loss: 0.6187 - val_y1_output_loss: 0.2104 - val_y2_output_loss: 0.4052 - val_y1_output_root_mean_squared_error: 0.4578 - val_y2_output_root_mean_squared_error: 0.6396
# Epoch 462/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3372 - y1_output_loss: 0.1060 - y2_output_loss: 0.2338 - y1_output_root_mean_squared_error: 0.3212 - y2_output_root_mean_squared_error: 0.4838 - val_loss: 1.2626 - val_y1_output_loss: 0.5238 - val_y2_output_loss: 0.7473 - val_y1_output_root_mean_squared_error: 0.7128 - val_y2_output_root_mean_squared_error: 0.8686
# Epoch 463/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4679 - y1_output_loss: 0.1593 - y2_output_loss: 0.3091 - y1_output_root_mean_squared_error: 0.3964 - y2_output_root_mean_squared_error: 0.5575 - val_loss: 0.5871 - val_y1_output_loss: 0.1754 - val_y2_output_loss: 0.4093 - val_y1_output_root_mean_squared_error: 0.4113 - val_y2_output_root_mean_squared_error: 0.6465
# Epoch 464/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3559 - y1_output_loss: 0.1158 - y2_output_loss: 0.2417 - y1_output_root_mean_squared_error: 0.3389 - y2_output_root_mean_squared_error: 0.4909 - val_loss: 0.6751 - val_y1_output_loss: 0.1828 - val_y2_output_loss: 0.4887 - val_y1_output_root_mean_squared_error: 0.4267 - val_y2_output_root_mean_squared_error: 0.7022
# Epoch 465/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3762 - y1_output_loss: 0.1099 - y2_output_loss: 0.2662 - y1_output_root_mean_squared_error: 0.3322 - y2_output_root_mean_squared_error: 0.5156 - val_loss: 0.6614 - val_y1_output_loss: 0.1934 - val_y2_output_loss: 0.4770 - val_y1_output_root_mean_squared_error: 0.4283 - val_y2_output_root_mean_squared_error: 0.6913
# Epoch 466/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3754 - y1_output_loss: 0.1037 - y2_output_loss: 0.2730 - y1_output_root_mean_squared_error: 0.3214 - y2_output_root_mean_squared_error: 0.5216 - val_loss: 0.6761 - val_y1_output_loss: 0.2042 - val_y2_output_loss: 0.4580 - val_y1_output_root_mean_squared_error: 0.4491 - val_y2_output_root_mean_squared_error: 0.6887
# Epoch 467/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3175 - y1_output_loss: 0.1024 - y2_output_loss: 0.2255 - y1_output_root_mean_squared_error: 0.3207 - y2_output_root_mean_squared_error: 0.4633 - val_loss: 1.8716 - val_y1_output_loss: 0.2880 - val_y2_output_loss: 1.5530 - val_y1_output_root_mean_squared_error: 0.5441 - val_y2_output_root_mean_squared_error: 1.2552
# Epoch 468/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.8210 - y1_output_loss: 0.2131 - y2_output_loss: 0.6149 - y1_output_root_mean_squared_error: 0.4602 - y2_output_root_mean_squared_error: 0.7805 - val_loss: 0.9241 - val_y1_output_loss: 0.2761 - val_y2_output_loss: 0.6605 - val_y1_output_root_mean_squared_error: 0.5311 - val_y2_output_root_mean_squared_error: 0.8013
# Epoch 469/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3526 - y1_output_loss: 0.1206 - y2_output_loss: 0.2306 - y1_output_root_mean_squared_error: 0.3480 - y2_output_root_mean_squared_error: 0.4812 - val_loss: 0.7372 - val_y1_output_loss: 0.1865 - val_y2_output_loss: 0.5330 - val_y1_output_root_mean_squared_error: 0.4309 - val_y2_output_root_mean_squared_error: 0.7426
# Epoch 470/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3541 - y1_output_loss: 0.1154 - y2_output_loss: 0.2372 - y1_output_root_mean_squared_error: 0.3400 - y2_output_root_mean_squared_error: 0.4884 - val_loss: 0.6739 - val_y1_output_loss: 0.2121 - val_y2_output_loss: 0.4532 - val_y1_output_root_mean_squared_error: 0.4629 - val_y2_output_root_mean_squared_error: 0.6780
# Epoch 471/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3632 - y1_output_loss: 0.1154 - y2_output_loss: 0.2509 - y1_output_root_mean_squared_error: 0.3352 - y2_output_root_mean_squared_error: 0.5009 - val_loss: 1.5465 - val_y1_output_loss: 0.6954 - val_y2_output_loss: 0.8443 - val_y1_output_root_mean_squared_error: 0.8366 - val_y2_output_root_mean_squared_error: 0.9201
# Epoch 472/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4766 - y1_output_loss: 0.1606 - y2_output_loss: 0.3173 - y1_output_root_mean_squared_error: 0.3993 - y2_output_root_mean_squared_error: 0.5631 - val_loss: 1.0030 - val_y1_output_loss: 0.3134 - val_y2_output_loss: 0.6642 - val_y1_output_root_mean_squared_error: 0.5619 - val_y2_output_root_mean_squared_error: 0.8290
# Epoch 473/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.5817 - y1_output_loss: 0.1532 - y2_output_loss: 0.4285 - y1_output_root_mean_squared_error: 0.3894 - y2_output_root_mean_squared_error: 0.6558 - val_loss: 0.9267 - val_y1_output_loss: 0.3116 - val_y2_output_loss: 0.5949 - val_y1_output_root_mean_squared_error: 0.5571 - val_y2_output_root_mean_squared_error: 0.7851
# Epoch 474/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4610 - y1_output_loss: 0.1140 - y2_output_loss: 0.3467 - y1_output_root_mean_squared_error: 0.3376 - y2_output_root_mean_squared_error: 0.5890 - val_loss: 0.6534 - val_y1_output_loss: 0.1798 - val_y2_output_loss: 0.4609 - val_y1_output_root_mean_squared_error: 0.4217 - val_y2_output_root_mean_squared_error: 0.6896
# Epoch 475/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3425 - y1_output_loss: 0.1203 - y2_output_loss: 0.2205 - y1_output_root_mean_squared_error: 0.3473 - y2_output_root_mean_squared_error: 0.4711 - val_loss: 0.6037 - val_y1_output_loss: 0.1717 - val_y2_output_loss: 0.4444 - val_y1_output_root_mean_squared_error: 0.4124 - val_y2_output_root_mean_squared_error: 0.6585
# Epoch 476/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4797 - y1_output_loss: 0.1398 - y2_output_loss: 0.3363 - y1_output_root_mean_squared_error: 0.3749 - y2_output_root_mean_squared_error: 0.5823 - val_loss: 0.6346 - val_y1_output_loss: 0.2183 - val_y2_output_loss: 0.4136 - val_y1_output_root_mean_squared_error: 0.4593 - val_y2_output_root_mean_squared_error: 0.6509
# Epoch 477/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3984 - y1_output_loss: 0.1091 - y2_output_loss: 0.2860 - y1_output_root_mean_squared_error: 0.3314 - y2_output_root_mean_squared_error: 0.5372 - val_loss: 0.5565 - val_y1_output_loss: 0.1654 - val_y2_output_loss: 0.3966 - val_y1_output_root_mean_squared_error: 0.4007 - val_y2_output_root_mean_squared_error: 0.6292
# Epoch 478/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3998 - y1_output_loss: 0.1134 - y2_output_loss: 0.2848 - y1_output_root_mean_squared_error: 0.3372 - y2_output_root_mean_squared_error: 0.5349 - val_loss: 0.7417 - val_y1_output_loss: 0.2268 - val_y2_output_loss: 0.5010 - val_y1_output_root_mean_squared_error: 0.4759 - val_y2_output_root_mean_squared_error: 0.7178
# Epoch 479/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3593 - y1_output_loss: 0.1173 - y2_output_loss: 0.2409 - y1_output_root_mean_squared_error: 0.3426 - y2_output_root_mean_squared_error: 0.4919 - val_loss: 0.5587 - val_y1_output_loss: 0.1559 - val_y2_output_loss: 0.4109 - val_y1_output_root_mean_squared_error: 0.3867 - val_y2_output_root_mean_squared_error: 0.6397
# Epoch 480/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3023 - y1_output_loss: 0.1021 - y2_output_loss: 0.1996 - y1_output_root_mean_squared_error: 0.3198 - y2_output_root_mean_squared_error: 0.4473 - val_loss: 1.0353 - val_y1_output_loss: 0.3879 - val_y2_output_loss: 0.6329 - val_y1_output_root_mean_squared_error: 0.6218 - val_y2_output_root_mean_squared_error: 0.8054
# Epoch 481/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3559 - y1_output_loss: 0.1221 - y2_output_loss: 0.2330 - y1_output_root_mean_squared_error: 0.3503 - y2_output_root_mean_squared_error: 0.4829 - val_loss: 0.6959 - val_y1_output_loss: 0.2084 - val_y2_output_loss: 0.4865 - val_y1_output_root_mean_squared_error: 0.4560 - val_y2_output_root_mean_squared_error: 0.6986
# Epoch 482/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.7294 - y1_output_loss: 0.2803 - y2_output_loss: 0.4486 - y1_output_root_mean_squared_error: 0.5303 - y2_output_root_mean_squared_error: 0.6694 - val_loss: 1.1683 - val_y1_output_loss: 0.2634 - val_y2_output_loss: 0.9106 - val_y1_output_root_mean_squared_error: 0.5048 - val_y2_output_root_mean_squared_error: 0.9558
# Epoch 483/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5042 - y1_output_loss: 0.1555 - y2_output_loss: 0.3447 - y1_output_root_mean_squared_error: 0.3960 - y2_output_root_mean_squared_error: 0.5894 - val_loss: 0.5432 - val_y1_output_loss: 0.1694 - val_y2_output_loss: 0.3699 - val_y1_output_root_mean_squared_error: 0.4071 - val_y2_output_root_mean_squared_error: 0.6144
# Epoch 484/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3257 - y1_output_loss: 0.1058 - y2_output_loss: 0.2181 - y1_output_root_mean_squared_error: 0.3264 - y2_output_root_mean_squared_error: 0.4681 - val_loss: 0.6848 - val_y1_output_loss: 0.2211 - val_y2_output_loss: 0.4550 - val_y1_output_root_mean_squared_error: 0.4632 - val_y2_output_root_mean_squared_error: 0.6858
# Epoch 485/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.2992 - y1_output_loss: 0.1106 - y2_output_loss: 0.1917 - y1_output_root_mean_squared_error: 0.3298 - y2_output_root_mean_squared_error: 0.4364 - val_loss: 1.1892 - val_y1_output_loss: 0.4998 - val_y2_output_loss: 0.6613 - val_y1_output_root_mean_squared_error: 0.7115 - val_y2_output_root_mean_squared_error: 0.8264
# Epoch 486/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3721 - y1_output_loss: 0.1331 - y2_output_loss: 0.2357 - y1_output_root_mean_squared_error: 0.3665 - y2_output_root_mean_squared_error: 0.4876 - val_loss: 0.5644 - val_y1_output_loss: 0.1571 - val_y2_output_loss: 0.4171 - val_y1_output_root_mean_squared_error: 0.3904 - val_y2_output_root_mean_squared_error: 0.6419
# Epoch 487/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4054 - y1_output_loss: 0.1231 - y2_output_loss: 0.2808 - y1_output_root_mean_squared_error: 0.3506 - y2_output_root_mean_squared_error: 0.5314 - val_loss: 0.7688 - val_y1_output_loss: 0.1681 - val_y2_output_loss: 0.6064 - val_y1_output_root_mean_squared_error: 0.3981 - val_y2_output_root_mean_squared_error: 0.7812
# Epoch 488/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.5467 - y1_output_loss: 0.1912 - y2_output_loss: 0.3565 - y1_output_root_mean_squared_error: 0.4358 - y2_output_root_mean_squared_error: 0.5973 - val_loss: 0.9438 - val_y1_output_loss: 0.2451 - val_y2_output_loss: 0.7744 - val_y1_output_root_mean_squared_error: 0.4772 - val_y2_output_root_mean_squared_error: 0.8462
# Epoch 489/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4905 - y1_output_loss: 0.1545 - y2_output_loss: 0.3337 - y1_output_root_mean_squared_error: 0.3924 - y2_output_root_mean_squared_error: 0.5801 - val_loss: 0.7065 - val_y1_output_loss: 0.2532 - val_y2_output_loss: 0.4461 - val_y1_output_root_mean_squared_error: 0.5084 - val_y2_output_root_mean_squared_error: 0.6694
# Epoch 490/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3345 - y1_output_loss: 0.1233 - y2_output_loss: 0.2254 - y1_output_root_mean_squared_error: 0.3377 - y2_output_root_mean_squared_error: 0.4695 - val_loss: 2.1444 - val_y1_output_loss: 0.8951 - val_y2_output_loss: 1.2120 - val_y1_output_root_mean_squared_error: 0.9456 - val_y2_output_root_mean_squared_error: 1.1181
# Epoch 491/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4128 - y1_output_loss: 0.1594 - y2_output_loss: 0.2510 - y1_output_root_mean_squared_error: 0.4007 - y2_output_root_mean_squared_error: 0.5022 - val_loss: 0.8169 - val_y1_output_loss: 0.1964 - val_y2_output_loss: 0.6236 - val_y1_output_root_mean_squared_error: 0.4433 - val_y2_output_root_mean_squared_error: 0.7877
# Epoch 492/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3122 - y1_output_loss: 0.1079 - y2_output_loss: 0.2052 - y1_output_root_mean_squared_error: 0.3294 - y2_output_root_mean_squared_error: 0.4513 - val_loss: 1.4151 - val_y1_output_loss: 0.3265 - val_y2_output_loss: 1.0750 - val_y1_output_root_mean_squared_error: 0.5655 - val_y2_output_root_mean_squared_error: 1.0466
# Epoch 493/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4380 - y1_output_loss: 0.1190 - y2_output_loss: 0.3199 - y1_output_root_mean_squared_error: 0.3450 - y2_output_root_mean_squared_error: 0.5648 - val_loss: 0.6486 - val_y1_output_loss: 0.1934 - val_y2_output_loss: 0.4472 - val_y1_output_root_mean_squared_error: 0.4374 - val_y2_output_root_mean_squared_error: 0.6762
# Epoch 494/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3307 - y1_output_loss: 0.0990 - y2_output_loss: 0.2295 - y1_output_root_mean_squared_error: 0.3155 - y2_output_root_mean_squared_error: 0.4808 - val_loss: 0.5807 - val_y1_output_loss: 0.1560 - val_y2_output_loss: 0.4155 - val_y1_output_root_mean_squared_error: 0.3894 - val_y2_output_root_mean_squared_error: 0.6551
# Epoch 495/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.7247 - y1_output_loss: 0.1848 - y2_output_loss: 0.5383 - y1_output_root_mean_squared_error: 0.4280 - y2_output_root_mean_squared_error: 0.7359 - val_loss: 0.9057 - val_y1_output_loss: 0.2424 - val_y2_output_loss: 0.6525 - val_y1_output_root_mean_squared_error: 0.4842 - val_y2_output_root_mean_squared_error: 0.8193
# Epoch 496/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3588 - y1_output_loss: 0.1091 - y2_output_loss: 0.2474 - y1_output_root_mean_squared_error: 0.3317 - y2_output_root_mean_squared_error: 0.4988 - val_loss: 0.6060 - val_y1_output_loss: 0.2109 - val_y2_output_loss: 0.3908 - val_y1_output_root_mean_squared_error: 0.4549 - val_y2_output_root_mean_squared_error: 0.6318
# Epoch 497/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4055 - y1_output_loss: 0.1142 - y2_output_loss: 0.2896 - y1_output_root_mean_squared_error: 0.3366 - y2_output_root_mean_squared_error: 0.5405 - val_loss: 0.5960 - val_y1_output_loss: 0.2059 - val_y2_output_loss: 0.3811 - val_y1_output_root_mean_squared_error: 0.4541 - val_y2_output_root_mean_squared_error: 0.6244
# Epoch 498/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3319 - y1_output_loss: 0.1106 - y2_output_loss: 0.2186 - y1_output_root_mean_squared_error: 0.3339 - y2_output_root_mean_squared_error: 0.4695 - val_loss: 0.6327 - val_y1_output_loss: 0.2167 - val_y2_output_loss: 0.4173 - val_y1_output_root_mean_squared_error: 0.4559 - val_y2_output_root_mean_squared_error: 0.6518
# Epoch 499/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.2985 - y1_output_loss: 0.0987 - y2_output_loss: 0.1978 - y1_output_root_mean_squared_error: 0.3155 - y2_output_root_mean_squared_error: 0.4461 - val_loss: 0.5157 - val_y1_output_loss: 0.1587 - val_y2_output_loss: 0.3625 - val_y1_output_root_mean_squared_error: 0.3909 - val_y2_output_root_mean_squared_error: 0.6024
# Epoch 500/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3546 - y1_output_loss: 0.1058 - y2_output_loss: 0.2515 - y1_output_root_mean_squared_error: 0.3258 - y2_output_root_mean_squared_error: 0.4984 - val_loss: 1.0601 - val_y1_output_loss: 0.1835 - val_y2_output_loss: 0.9030 - val_y1_output_root_mean_squared_error: 0.4136 - val_y2_output_root_mean_squared_error: 0.9429

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 36us/sample - loss: 1.0601 - y1_output_loss: 0.1715 - y2_output_loss: 0.8903 - y1_output_root_mean_squared_error: 0.4136 - y2_output_root_mean_squared_error: 0.9429
# Loss = 1.0600850396342092, Y1_loss = 0.171548992395401, Y1_mse = 0.41362425684928894, Y2_loss = 0.8903063535690308, Y2_mse = 0.9428679943084717

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
